# %%
# !pip install snscrape
import snscrape.modules.twitter as sntwitter
import pandas as pd
twt_list = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('Qatar since:2022-10-18 until:2022-12-28').get_items()):
    if i>100000:#number of tweets you want to scrape
        break
    twt_list.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
    
# Creating a dataframe from the tweets list above
tweets_df = pd.DataFrame(twt_list, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])
tweets_df
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 59 kB 3.0 MB/s
# ...
#                         Datetime             Tweet Id  \
# 0      2022-12-27 23:10:57+00:00  1607876720173932544
# 1      2022-12-27 23:10:48+00:00  1607876680739176448
# 2      2022-12-27 23:10:45+00:00  1607876670685605889
# 3      2022-12-27 23:10:40+00:00  1607876646643671042
# 4      2022-12-27 23:10:38+00:00  1607876641274925056
# ...                          ...                  ...
# 99996  2022-12-21 13:55:30+00:00  1605562610639937536
# 99997  2022-12-21 13:55:29+00:00  1605562602729390081
# 99998  2022-12-21 13:55:26+00:00  1605562592012795904
# 99999  2022-12-21 13:55:26+00:00  1605562591136604162
# 100000 2022-12-21 13:55:23+00:00  1605562579350220800
#
#                                                      Text         Username
# 0       @LuisGasulla Que comentario pelotudo. Al #MUFA...     diego_chamot
# ...

# %%
tweets_df.to_csv("tweets.csv", index=False)
